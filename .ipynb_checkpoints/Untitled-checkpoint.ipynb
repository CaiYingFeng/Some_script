# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
import numpy as np

lena = mpimg.imread("/media/autolab/disk_4T/cyf/localization/plot/1606405085.50662051.png") # 读取和代码处于同一目录下的 lena.png
# 此时 lena 就已经是一个 np.array 了，可以对它进行任意处理
print(lena.shape) #(512, 512, 3)

plt.imshow(lena) # 显示图片
# Out:
# (510, 960, 3)

# %%
from PIL import Image
from pylab import imshow
from pylab import array
from pylab import plot
from pylab import title
 
# 读取图像到数组中
im = Image.open("/media/autolab/disk_4T/cyf/localization/plot/1606405085.50662051_origin.png")
# 绘制图像
imshow(im)
# 一些点
kp=np.load('/media/autolab/disk_4T/cyf/localization/plot/keypoints.npy')
x=[]
y=[]
print(len(kp))
for i in range(len(kp)):
    x.append(2*kp[i][0])
    y.append(2*kp[i][1])
# 使用红色星状标记绘制点
plot(x,y,'r.')
# 绘制连接前两个点的线
#plot(x[:2],y[:2])
# 添加标题，显示绘制的图像
plt.axis('off') # 不显示坐标轴
title('Plotting: "empire.jpg"')
# show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-aa23939f158e> in <module>
#       8 im = Image.open("/media/autolab/disk_4T/cyf/localization/plot/1606405085.50662051_origin.png")
#       9 # 绘制图像
# ---> 10 imshow(im,aspect='max')
#      11 # 一些点
#      12 kp=np.load('/media/autolab/disk_4T/cyf/localization/plot/keypoints.npy')
#
# ~/anaconda3/envs/cyf/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2712         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2713         url=url, **({"data": data} if data is not None else {}),
# -> 2714         **kwargs)
#    2715     sci(__ret)
#    2716     return __ret
#
# ~/anaconda3/envs/cyf/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/cyf/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5516         if aspect is None:
#    5517             aspect = rcParams['image.aspect']
# -> 5518         self.set_aspect(aspect)
#    5519         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5520                               filternorm=filternorm, filterrad=filterrad,
#
# ~/anaconda3/envs/cyf/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_aspect(self, aspect, adjustable, anchor, share)
#    1340             aspect = 1
#    1341         if not cbook._str_equal(aspect, 'auto'):
# -> 1342             aspect = float(aspect)  # raise ValueError if necessary
#    1343
#    1344         if share:
#
# ValueError: could not convert string to float: 'max'
